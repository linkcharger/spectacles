# %%
import pandas as pd

# %%
#################################################### stamp tax ####################################################

# %%
df = pd.read_stata('2_occupational/2_Stamp tax - prices of apprenticeships/st_1710_1810.dta')
df
# Out:
#         new_obs  period  year apprentice_surname app_forename master_surname  \
# 0        478874     2.0   0.0               Oram         John          Swift
# 1        485866     NaN   0.0
# 2        489457     NaN   0.0
# 3        403133     2.0   0.0            Bennett          Wm.        Caunter
# 4        362653     2.0   0.0              Moore        Peter        Wensley
# ...         ...     ...   ...                ...          ...            ...
# 515890   425642     2.0   NaN              Oates          Jn.          Green
# 515891   483638     2.0   NaN           Matthias         Tho.          Owens
# 515892   425630     2.0   NaN             Wright          Jn.          Rider
# 515893   425654     2.0   NaN            Clement          Wm.          House
# 515894   425646     2.0   NaN             Bayley          Jn.          Jones
#
#        master_forename                 master_location       location_1  \
# ...

# %%
df.to_excel('2_occupational/2_Stamp tax - prices of apprenticeships/stamp-tax_1710-1810.xlsx')

# %%
df = pd.read_stata('2_occupational/2_Stamp tax - prices of apprenticeships/ST_analysis_core.dta')
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\stata.py:1514: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   warnings.warn(msg, UnicodeWarning)
#         row_id  year  circa_year premium_ app_forename apprentice_surname  \
# 0            1  1714           0       15       Jeremy            Trueman
# 1            2  1714           0        0       Joseph           Rabbitte
# 2            3  1731           0        8      Abraham            PRESTON
# 3            4  1713           0        0                            Wood
# 4            5  1720           0        2         John             Archer
# ...        ...   ...         ...      ...          ...                ...
# ...

# %%
df.to_excel('2_occupational/2_Stamp tax - prices of apprenticeships/stamp-tax_analysis.xlsx')

# %%
#################################################### baptism records ####################################################

# %%
df = pd.read_stata('2_occupational/oc - Male occupational data from English parish registers/Summary (UKDA-5398)/data.dta')
df
# Out:
#                file_name  file_id     id         porid     ruid   por  \
# 0       bed_county_table        1      1  BED/001/rose  BED/001  rose
# 1       bed_county_table        1      2  BED/001/rose  BED/001  rose
# 2       bed_county_table        1      3  BED/001/rose  BED/001  rose
# 3       bed_county_table        1      4  BED/001/rose  BED/001  rose
# 4       bed_county_table        1      5  BED/001/rose  BED/001  rose
# ...                  ...      ...    ...           ...      ...   ...
# 135874  ywr_county_table       23  17702  YWR/339/rose  YWR/339  rose
# 135875  ywr_county_table       23  17703  YWR/339/rose  YWR/339  rose
# 135876  ywr_county_table       23  17704  YWR/339/rose  YWR/339  rose
# 135877  ywr_county_table       23  17705  YWR/339/rose  YWR/339  rose
# 135878  ywr_county_table       23  17706  YWR/339/rose  YWR/339  rose
#
#             runame utype       parish     window  numevents   pcs   sr  \
# ...

# %%
df.to_excel('2_occupational/oc - Male occupational data from English parish registers/summary_data.xlsx')

# %%
df = pd.read_stata('2_occupational/oc - Male occupational data from English parish registers/Raw (UKDA-5397)/raw.dta')
df
# Out:
#          id_file_name file_name      runame     ruid   por       dstart  \
# 0                 1.0       bed    Ampthill  BED/001     1  00 Jan 1702
# 1                 1.0       bed    Ampthill  BED/001     1  00 Jan 1702
# 2                 1.0       bed    Ampthill  BED/001     1  00 Jan 1702
# 3                 1.0       bed    Ampthill  BED/001     1  00 Jan 1702
# 4                 1.0       bed    Ampthill  BED/001     1  00 Jan 1702
# ...               ...       ...         ...      ...   ...          ...
# 1023146          26.0      ywr4  Barnby Dun  YWR/339  rose  31 Jan 1813
# 1023147          26.0      ywr4  Barnby Dun  YWR/339  rose  31 Jan 1813
# 1023148          26.0      ywr4  Barnby Dun  YWR/339  rose  31 Jan 1813
# 1023149          26.0      ywr4  Barnby Dun  YWR/339  rose  31 Jan 1813
# 1023150          26.0      ywr4  Barnby Dun  YWR/339  rose  31 Jan 1813
#
#                 dend xyears   sr                                 archive  \
# ...

# %%
df.to_excel('2_occupational/oc - Male occupational data from English parish registers/raw_data.xlsx')

# %%
#################################################### occupational census ####################################################

# %%
df = pd.read_stata('2_occupational/4_1851 census/1851_occu_pt_eng.dta')
df
# Out:
#        town                        regcounty sex   age  \
# 0      Bath                         Somerset   F  0-19
# 1      Bath                         Somerset   F  0-19
# 2      Bath                         Somerset   F  0-19
# 3      Bath                         Somerset   F  0-19
# 4      Bath                         Somerset   F  0-19
# ...     ...                              ...  ..   ...
# 38951  York  Yorkshire East Riding with York   M   20+
# 38952  York  Yorkshire East Riding with York   M   20+
# 38953  York  Yorkshire East Riding with York   M   20+
# 38954  York  Yorkshire East Riding with York   M   20+
# 38955  York  Yorkshire East Riding with York   M   20+
#
#                                        occ   n
# 0         actors and others about theatres   4
# 1                                annuitant   8
# 2                                    baker   4
# 3                             bonnet-maker   3
# 4                               bookseller   1
# ...

# %%
df.to_excel('2_occupational/4_1851 census/1851_census.xlsx')

# %%
df = pd.read_stata('2_occupational/4_1851 census/occ_ages_county_eng_1851.dta')
df
# Out:
#                     regcounty sex                              occ    range  \
# 0                Bedfordshire   F  agricultural labourer (outdoor)  "10-14"
# 1                Bedfordshire   F  agricultural labourer (outdoor)    15-19
# 2                Bedfordshire   F  agricultural labourer (outdoor)    20-24
# 3                Bedfordshire   F  agricultural labourer (outdoor)    25-29
# 4                Bedfordshire   F  agricultural labourer (outdoor)    30-34
# ...                       ...  ..                              ...      ...
# 186612  Yorkshire West Riding   M              worsted manufacture    70-74
# 186613  Yorkshire West Riding   M              worsted manufacture    75-79
# 186614  Yorkshire West Riding   M              worsted manufacture    80-84
# 186615  Yorkshire West Riding   M              worsted manufacture    85-89
# 186616  Yorkshire West Riding   M              worsted manufacture    90-94
#
#         min  max    n
# 0        10   14    4
# ...

# %%
df.to_excel('2_occupational/4_1851 census/1851_census_age-distributions.xlsx')
